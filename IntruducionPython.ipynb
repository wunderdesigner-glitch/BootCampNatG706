# %% [markdown]
# <a href="https://colab.research.google.com/github/wunderdesigner-glitch/BootCampNatG706/blob/master/IntruducionPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📋Conocimientos previos
#
# * Qué es un programa
# * Como escribir e interpretar instrucciones en Python
# * Qué es una variable

# %%
# Tipos de datos
entero=10
decimal=10.3
texto="Manizales"
lista=[1,2,3,4]
booleano=True
booleano=False
dicionario={"Nombre":"Luis Fernando Gallego"}
print(type(entero))
print(type(decimal))
print(type(texto))
print(type(lista))
print(type(booleano))
print(type(dicionario))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'list'>
# <class 'bool'>
# <class 'dict'>

# %% [markdown]
# # Operaciones matemáticas y lógicas:
# * Operadores básicos: +,-,*,/,**,%,//

# %%
print('🌹'*10)
a=10
b=3
suma=a+b
resta=a-b
mult=a*b
pt=a**b
div=a/b
div=round(div,2)
ent=a//b
re=a%b
print("Suma", a, "+", b,"=",suma)
print(f"Suma {a} + {b} = {suma}")
print(f"la operación de el operador % permite obtener el residuo de una división ejemplo {a} % {b} = {a%b}")
print(f"la operación de el operador // permite obtener el cociente de una división ejemplo {a} // {b} = {a//b}")
print(f"la operación de el operador / permite obtener la división ejemplo {a} / {b} = {a/b}")
print(f"la función round  permite redondear un valor  ejemplo {a} / {b} = {div}")
print(f"la función round  permite redondear un valor  ejemplo {a} / {b} = {round((a/b),2)}")
print(f"la función round  permite redondear un valor  ejemplo {a} / {b} = {round(a/b)}")
print(f"la operación de el operador ** permite elevar {a} a la {b}  ejemplo {a} ** {b} = {a**b}")
# Out:
# 🌹🌹🌹🌹🌹🌹🌹🌹🌹🌹
# Suma 10 + 3 = 13
# Suma 10 + 3 = 13
# la operación de el operador % permite obtener el residuo de una división ejemplo 10 % 3 = 1
# la operación de el operador // permite obtener el cociente de una división ejemplo 10 // 3 = 3
# la operación de el operador / permite obtener la división ejemplo 10 / 3 = 3.3333333333333335
# la función round  permite redondear un valor  ejemplo 10 / 3 = 3.33
# la función round  permite redondear un valor  ejemplo 10 / 3 = 3.33
# la función round  permite redondear un valor  ejemplo 10 / 3 = 3
# la operación de el operador ** permite elevar 10 a la 3  ejemplo 10 ** 3 = 1000

# %% [markdown]
# # Comparaciones: >, <, >=, <=, == !=

# %%
a=10
b=3
c=10
print(a>b)
print(a<b)
print(a>=b)
print(a<=b)
print(a==c)
print(a!=c)
# Out:
# True
# False
# True
# False
# True
# False

# %%
# Ejemplo if
edad = 18
if edad >= 18:
  print("Eres mayor de edad")
else:
  print("Eres menor de edad")
print("ok")
# Out:
# Eres mayor de edad
# ok

# %%
# Estructuras de repetición
#ejemplo for
for i in range(5):
  print("Número",i)
# Out:
# Número 0
# Número 1
# Número 2
# Número 3
# Número 4
